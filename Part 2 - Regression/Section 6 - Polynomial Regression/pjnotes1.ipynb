# %% [markdown]
# # Polynomial linear regression

# %% [markdown]
# y = b0 + b1x1 + b2(x1)^2 + b3(x1)^3 +...+ bn*(x1)^n <br>
# <i>linear and non linear refers to the coefficients.</i> i.e. the equations where we can replace coeffs. with other coeffs to turn the equation into linear one in regards to the coeff.<p>
#     since only very few data we have what we do is, we don't divide our data into the training and testing ones.<p>
#    Now we try to compare the lin. reg model with the poly lin reg model.<br>
#     For polynomial regression model we create <b>new matrix of features X_poly where there will be X, X^2, X^3... till the power we want.</b> Hence we will transform X with only one independent variable to X_poly with new independent variables.<i>For this we use the sklearn.preprocessing PolynomialFeatures we use degree parameter to tune the model.</i><p>
#        for more continuous curve what we do is we don't use X which is 1 to 10 incremented by 1, we use 1 to 10 increamented by 0.1 instead. For that we add the<br> <b>X_grid = np.arange(min(X,max(X),0.1) </b><br>
#         this will give us a vector to make it a matrix we use the<br><b> X_grid= X_grid.reshape(len(X_grid),1)</b>

# %% [markdown]
# ![Screenshot%20from%202018-07-05%2011-03-19.png](attachment:Screenshot%20from%202018-07-05%2011-03-19.png)
