# %% [markdown]
# # Thompson's  sampling Algo
# #### To solve Multi-Armed Bandit problem:
# ![Screenshot%20from%202018-07-10%2012-08-40.png](attachment:Screenshot%20from%202018-07-10%2012-08-40.png)
#
# ![Screenshot%20from%202018-07-10%2012-10-39.png](attachment:Screenshot%20from%202018-07-10%2012-10-39.png)
#
# ![Screenshot%20from%202018-07-10%2012-11-11.png](attachment:Screenshot%20from%202018-07-10%2012-11-11.png)
#
# We try to determine the point where the actual expected value might lie.
# <br>
# ![Screenshot%20from%202018-07-10%2012-16-09.png](attachment:Screenshot%20from%202018-07-10%2012-16-09.png)
# With help of the observations we try to explain what is happening with the mathematical model.<br>
# ![Screenshot%20from%202018-07-10%2012-17-51.png](attachment:Screenshot%20from%202018-07-10%2012-17-51.png)
# <p>
#     Now we pull out the values and try to get our own bandit configuration. we choose the best bandit among them.<br>
#
# ![Screenshot%20from%202018-07-10%2012-21-16.png](attachment:Screenshot%20from%202018-07-10%2012-21-16.png)
#
# ![Screenshot%20from%202018-07-10%2012-22-07.png](attachment:Screenshot%20from%202018-07-10%2012-22-07.png)
#
# ![Screenshot%20from%202018-07-10%2012-22-19.png](attachment:Screenshot%20from%202018-07-10%2012-22-19.png)
#
# ![Screenshot%20from%202018-07-10%2012-21-58.png](attachment:Screenshot%20from%202018-07-10%2012-21-58.png)
#
# ![Screenshot%20from%202018-07-10%2012-21-55.png](attachment:Screenshot%20from%202018-07-10%2012-21-55.png)
#
# <p>
#
#  agian we pull the lever and see the new info. and then we adjust our beliefs with the new observed value. This way the distributions are refined.<br>

# %% [markdown]
# ### UCB vs Thompson's sampling
# ![Screenshot%20from%202018-07-10%2012-55-10.png](attachment:Screenshot%20from%202018-07-10%2012-55-10.png)

# %% [markdown]
# ### Thomson's sampling for CTR marketing campaign

# %%
#Thomson's sampling
#importing the libs
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
# Importing the dataset
dataset = pd.read_csv('Ads_CTR_Optimisation.csv')

#Implementing UCB
import random
N = 10000
d = 10
ads_selected = []
numbers_of_rewards_1 = [0] * d
numbers_of_rewards_0 = [0] * d
total_reward = 0
#for each version of ad average reward and confidence interval
for n in range(0,N):
    ad = 0
    max_random = 0
    for i in range(0,d):
        random_beta = random.betavariate(numbers_of_rewards_1[i]+1,numbers_of_rewards_0[i]+1)
        if(random_beta>max_random):
            max_random = random_beta
            ad = i 
    ads_selected.append(ad)
    reward = dataset.values[n,ad]
    if reward == 1:
        numbers_of_rewards_1[ad] += 1
    else:
        numbers_of_rewards_0[ad] += 1
    total_reward += reward
    
    

# Visualising the results
plt.hist(ads_selected)
plt.title('Histogram of ads selections')
plt.xlabel('Ads')
plt.ylabel('Number of times each ad was selected')
plt.show()
