# %% [markdown]
# # Eclat model

# %% [markdown]
# Association rule with Eclat model is simpler version of Apriori model.
# <br>
# This model just has the <b> Eclat Support</b><br>
# ![Screenshot%20from%202018-07-09%2015-44-49.png](attachment:Screenshot%20from%202018-07-09%2015-44-49.png)![Screenshot%20from%202018-07-09%2015-42-34.png](attachment:Screenshot%20from%202018-07-09%2015-42-34.png)
