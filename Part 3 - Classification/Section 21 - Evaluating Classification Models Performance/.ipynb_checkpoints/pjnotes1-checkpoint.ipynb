# %% [markdown]
# # Model performance evaluation

# %% [markdown]
# ![Screenshot%20from%202018-07-08%2013-44-59.png](attachment:Screenshot%20from%202018-07-08%2013-44-59.png)

# %% [markdown]
# ### false +ves and -ves:
# ![Screenshot%20from%202018-07-08%2013-52-37.png](attachment:Screenshot%20from%202018-07-08%2013-52-37.png)
#
# ### Confusion matrix:
# ![Screenshot%20from%202018-07-08%2013-57-21.png](attachment:Screenshot%20from%202018-07-08%2013-57-21.png)
#
# ### Accuracy paradox:
# ![Screenshot%20from%202018-07-08%2013-59-47.png](attachment:Screenshot%20from%202018-07-08%2013-59-47.png)
#
# ![Screenshot%20from%202018-07-08%2013-59-25.png](attachment:Screenshot%20from%202018-07-08%2013-59-25.png)
#
# ### Cummulative accuracy profile:
# There is the black random model... where the ad is given to random set of people, Then we use some analysis and try to target the ad to the concerned users, this adds a little accuracy to our model, this is green one and the red one is the best that we can get, grey line however is the ideal line that the 10% selected ones will be the actual users of the product. ![Screenshot%20from%202018-07-08%2014-06-36.png](attachment:Screenshot%20from%202018-07-08%2014-06-36.png)
# <p>
#
# CAP != ROC(reciever operating characteristics)
#
# <p>
#
# We do CAP analysis to find if the red line we got is optimal or not, this is determined by the accuracy ratio:
# ![Screenshot%20from%202018-07-08%2014-09-26.png](attachment:Screenshot%20from%202018-07-08%2014-09-26.png)
#
# <b>The accuracy ratio is hard to calculate</b>
# so we use the other technique:
# ![Screenshot%20from%202018-07-08%2014-10-59.png](attachment:Screenshot%20from%202018-07-08%2014-10-59.png)
