# %% [markdown]
# # Naive bayes

# %% [markdown]
# ### Bayes theorem
#
# For naive bayes classifier, we use bayes theorem. Here in example we use it twice to determine the probability for a unknown point to be classified as one who walks or drives using bayes theorem.<br>
# ![Screenshot%20from%202018-07-08%2012-11-34.png](attachment:Screenshot%20from%202018-07-08%2012-11-34.png)
#
# ![Screenshot%20from%202018-07-08%2012-11-44.png](attachment:Screenshot%20from%202018-07-08%2012-11-44.png)
#
# ![Screenshot%20from%202018-07-08%2012-12-28.png](attachment:Screenshot%20from%202018-07-08%2012-12-28.png)
#
# ![Screenshot%20from%202018-07-08%2012-12-48.png](attachment:Screenshot%20from%202018-07-08%2012-12-48.png)
#
# ![Screenshot%20from%202018-07-08%2012-12-59.png](attachment:Screenshot%20from%202018-07-08%2012-12-59.png)

# %% [markdown]
# ### Given the features X we need to classify the person if he drives or walks. so we calculate posterior probability of given features in each case and the higher probability will give the classification for the person.
# <p>
#
# 1. #### we calculate prior prbability by:
# ![Screenshot%20from%202018-07-08%2012-16-51.png](attachment:Screenshot%20from%202018-07-08%2012-16-51.png)
# 2. #### we calculate marginal likelihood by:
#     <i>The radius of the circle can be controled using parameters</i>
#     ![Screenshot%20from%202018-07-08%2012-17-08.png](attachment:Screenshot%20from%202018-07-08%2012-17-08.png)
# 3. #### we calculate likelihood by:
#     ![Screenshot%20from%202018-07-08%2012-17-31.png](attachment:Screenshot%20from%202018-07-08%2012-17-31.png)
#
# 4. #### we calculate posterior probability plugging in bayes theorem
#
# 5. #### we calculate posterior probability for the ones who drive too using the features X.
#
# 6. #### here the posterior probabilities for a person to walk given the features X is 0.75 and same for him to drive is 0.25. Hence He walks.

# %% [markdown]
# ### Why Naive Bayes?
# based on Bayes theorem and it requires independent assumptions which may or may not be correct.
# Here for our example too the data is correlated and thus not independent and hence Bayes theorem is not a way to go. But still we use it so it maybe not the very best way to go sometimes.
# ### about P(X):
# it is the probability that randomly selected point from the dataset will exhibit the features similar to datapoint that we are about to add.
# since the P(X) is same for the denominator so to compare, we can just ignore one calculation.
#
# ![Screenshot%20from%202018-07-08%2012-32-39.png](attachment:Screenshot%20from%202018-07-08%2012-32-39.png)
#
# ### If we have more than 2 classes.
# for this we will have to calculate more posterior probabilities but after selecting some intuitively.

# %%
#Naive Bayes

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
# Importing the dataset
dataset = pd.read_csv('Social_Network_Ads.csv')
X = dataset.iloc[:, [2, 3]].values
y = dataset.iloc[:, 4].values

# Splitting the dataset into the Training set and Test set
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Fitting Naive Bayes classifier to the Training set
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train,y_train)


# Predicting the Test set results
y_pred = classifier.predict(X_test)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# Visualising the Training set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('NB Classifier (Training set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()

# Visualising the Test set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('NB Classifier (Test set)')
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.legend()
plt.show()
# Out:
# /home/prashant/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/prashant/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
